# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, GlobalAveragePooling2D, Dropout, Flatten
from tensorflow.keras.applications import VGG16
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_ds="/content/drive/MyDrive/datasetskincancer/data/train"
test_ds="/content/drive/MyDrive/datasetskincancer/data/test"

# %% [markdown]
# # Data preprocessing
# ****

# %%
os.listdir('/content/drive/MyDrive/datasetskincancer/data/train')
# Out:
# ['benign', 'malignant']

# %%
batch_size=32
img_size=224

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,
                             zoom_range=0.2,
                            width_shift_range=0.2,height_shift_range=0.2
                             )

test_datagen = ImageDataGenerator(rescale=1/255.)

train_generator = train_datagen.flow_from_directory(train_ds,
                                                target_size=(img_size, img_size),
                                                batch_size=batch_size,
                                                shuffle=True,
                                                class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_ds,
                                                    target_size=(img_size, img_size),
                                                    batch_size=batch_size,
                                                    shuffle=False,
                                                    class_mode='categorical')
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %%
labels = [k for k in train_generator.class_indices]
sample_generate = train_generator.__next__()

images = sample_generate[0]
titles = sample_generate[1]
plt.figure(figsize = (20 , 20))

for i in range(15):
    plt.subplot(5 , 5, i+1)
    plt.subplots_adjust(hspace = 0.3 , wspace = 0.3)
    plt.imshow(images[i])
    plt.title(f'Class: {labels[np.argmax(titles[i],axis=0)]}')
    plt.axis("off")

# %%
print(len(train_generator))
print(len(test_ds))
# Out:
# 83
# 50

# %%
import matplotlib.pyplot as plt
from skimage import io

# Load image
img_url = "/content/drive/MyDrive/datasetskincancer/data/train/benign/1001.jpg"
img = io.imread(img_url)

# Display image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from keras.layers import MaxPool2D

# %%
import numpy as np
from keras.layers import Dense,Flatten,Conv2D,Activation,Dropout

from keras import backend as K

import keras

from keras.models import Sequential, Model

from keras.models import load_model

from keras.optimizers import SGD

from keras.callbacks import EarlyStopping,ModelCheckpoint

from keras.layers import MaxPool2D

# %% [markdown]
# [link text](https://)# Build VGG_16 Model

# %%
from keras.layers import MaxPool2D

# %%
from keras.layers import MaxPool2D

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input

# Define input shape
input_shape = (img_size, img_size, 3)

# Create a Sequential model
model = Sequential([
    Input(shape=input_shape),  # Specify input shape in the first layer
    Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),

    Flatten(),
    Dense(units=4096, activation="relu"),
    Dense(units=4096, activation="relu"),
    Dense(units=2, activation="softmax")  # Assuming binary classification
])

# %% [markdown]
# #   Model summary

# %%
# Print the model summary

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4096)                │     102,764,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │           8,194 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 134,268,738 (512.19 MB)
#  Trainable params: 134,268,738 (512.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.optimizers import Adam
opt = Adam(learning_rate=0.00001)
model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                    epochs=100,
                    validation_data=test_generator)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 83/83 ━━━━━━━━━━━━━━━━━━━━
100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 695ms/step - accuracy: 0.9425 - loss: 0.1543 - val_accuracy: 0.8773 - val_loss: 0.3069
# Epoch 96/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 61s 686ms/step - accuracy: 0.9209 - loss: 0.1882 - val_accuracy: 0.8667 - val_loss: 0.3197
# Epoch 97/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 60s 686ms/step - accuracy: 0.9210 - loss: 0.1683 - val_accuracy: 0.8667 - val_loss: 0.2849
# Epoch 98/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 706ms/step - accuracy: 0.9243 - loss: 0.1743 - val_accuracy: 0.8682 - val_loss: 0.3052
# Epoch 99/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 726ms/step - accuracy: 0.9189 - loss: 0.1877 - val_accuracy: 0.8742 - val_loss: 0.2891
# Epoch 100/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 702ms/step - accuracy: 0.9436 - loss: 0.1362 - val_accuracy: 0.8697 - val_loss: 0.3120

# %%
n_categories = len(os.listdir('/content/drive/MyDrive/datasetskincancer/test'))# number of categories print(n_categories)

# %%
n_categories
# Out:
# 2

# %%
results =pd.DataFrame(history.history)
results.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.544937  0.682629      0.545455  0.654643
# 1  0.717482  0.523277      0.769697  0.484773
# 2  0.780053  0.453087      0.787879  0.419076
# 3  0.785362  0.424233      0.789394  0.396543
# 4  0.791430  0.419572      0.790909  0.395382

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['Train','Val'], loc= 'upper left')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
y_test_1 = test_generator.classes
y_pred_1 =model.predict(test_generator)
y_pred_1 = np.argmax(y_pred_1,axis=1)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step

# %%
results =model.evaluate(test_generator)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.8536 - loss: 0.3517

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix,precision_score, recall_score, roc_curve, f1_score

print(classification_report(y_test_1, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       360
#            1       0.85      0.87      0.86       300
#
#     accuracy                           0.87       660
#    macro avg       0.87      0.87      0.87       660
# weighted avg       0.87      0.87      0.87       660

# %%
# Calculate metrics for each class
precision_0 = precision_score(y_test_1, y_pred_1, pos_label=0)
recall_0 = recall_score(y_test_1, y_pred_1, pos_label=0)
f1_0 = f1_score(y_test_1, y_pred_1, pos_label=0)
precision_1 = precision_score(y_test_1, y_pred_1, pos_label=1)
recall_1 = recall_score(y_test_1, y_pred_1, pos_label=1)
f1_1 = f1_score(y_test_1, y_pred_1, pos_label=1)

# %%
# Calculate additional metrics
auc = roc_auc_score(y_test_1, y_pred_1)
tn, fp, fn, tp = confusion_matrix(y_test_1, y_pred_1).ravel()
precision = precision_score(y_test_1, y_pred_1)
recall = recall_score(y_test_1, y_pred_1)
specificity = tn / (tn + fp)
fdr = fp / (fp + tp)
fnr = fn / (fn + tp)
fpr = fp / (fp + tn)



# Print additional metrics for each class
print("Additional Metrics for Class 0:")
print(f"Precision: {precision_0:.2f}")
print(f"Recall: {recall_0:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"F1 Score: {f1_0:.2f}")
print(f"FDR: {fdr:.2f}")
print(f"FNR: {fnr:.2f}")
print(f"FPR: {fpr:.2f}\n")

print("Additional Metrics for Class 1:")
print(f"Precision: {precision_1:.2f}")
print(f"Recall: {recall_1:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"F1 Score: {f1_1:.2f}")
print(f"FDR: {fdr:.2f}")
print(f"FNR: {fnr:.2f}")
print(f"FPR: {fpr:.2f}\n")

# Print average metrics
precision_avg = (precision_0 + precision_1) / 2
recall_avg = (recall_0 + recall_1) / 2
f1_avg = (f1_0 + f1_1) / 2

print("Average Metrics:")
print(f"Precision: {precision_avg:.2f}")
print(f"Recall: {recall_avg:.2f}")
print(f"F1 Score: {f1_avg:.2f}")
print(f"AUC: {auc:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"FDR: {fdr:.2f}")
print(f"FNR: {fnr:.2f}")
print(f"FPR: {fpr:.2f}")
# Out:
# Additional Metrics for Class 0:
# Precision: 0.89
# Recall: 0.87
# Specificity: 0.87
# F1 Score: 0.88
# FDR: 0.15
# FNR: 0.13
# FPR: 0.13
#
# Additional Metrics for Class 1:
# Precision: 0.85
# Recall: 0.87
# Specificity: 0.87
# F1 Score: 0.86
# FDR: 0.15
# FNR: 0.13
# FPR: 0.13
#
# Average Metrics:
# Precision: 0.87
# Recall: 0.87
# F1 Score: 0.87
# AUC: 0.87
# Specificity: 0.87
# FDR: 0.15
# FNR: 0.13
# FPR: 0.13

# %%
import matplotlib.pyplot as plt
# Calculate ROC curve
fpr_values, tpr_values, _ = roc_curve(y_test_1, y_pred_1)

# Plot ROC curve
plt.figure()
plt.plot(fpr_values, tpr_values, color='darkorange', lw=2, label=f'ROC curve (area = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt

image_directory = '/content/drive/MyDrive/datasetskincancer/data/test/benign'
img_size = 224

images = []
for filename in os.listdir(image_directory):
    path = os.path.join(image_directory, filename)
    img = Image.open(path)
    img = img.resize((img_size, img_size))
    images.append(img)

images = np.array([np.array(img) for img in images])
images = images / 255.0

predictions = model.predict(images)

# Select image to display
img_index = 0

# Get predicted class label
class_label = np.argmax(predictions[img_index])

# Display image and predicted class label
plt.imshow(images[img_index])
plt.axis('off')
plt.title('Predicted class: ' + str(class_label))
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 564ms/step

# %%
for i in range(len(images)):
    predicted_class = np.argmax(predictions[i])
    class_probability = predictions[i, predicted_class]
    print(f'Predicted class for {i+1}.jpg : {labels[predicted_class]}')
    print('Class probability:', class_probability)
# Out:
# Predicted class for 1.jpg : malignant
# Class probability: 0.5850878
# Predicted class for 2.jpg : malignant
# Class probability: 0.7368306
# Predicted class for 3.jpg : benign
# Class probability: 0.9935171
# Predicted class for 4.jpg : benign
# Class probability: 0.9941606
# Predicted class for 5.jpg : benign
# Class probability: 0.999652
# Predicted class for 6.jpg : benign
# Class probability: 0.51357305
# Predicted class for 7.jpg : benign
# Class probability: 0.9999815
# Predicted class for 8.jpg : benign
# Class probability: 0.9999591
# Predicted class for 9.jpg : benign
# Class probability: 0.81169486
# Predicted class for 10.jpg : benign
# Class probability: 0.99977034
# Predicted class for 11.jpg : malignant
# Class probability: 0.84951335
# Predicted class for 12.jpg : benign
# Class probability: 0.9931195
# Predicted class for 13.jpg : benign
# Class probability: 0.86062384
# Predicted class for 14.jpg : malignant
# Class probability: 0.90777165
# Predicted class for 15.jpg : benign
# Class probability: 0.92543334
# Predicted class for 16.jpg : benign
# Class probability: 0.9984844
# Predicted class for 17.jpg : benign
# Class probability: 0.727459
# Predicted class for 18.jpg : benign
# Class probability: 0.50788546
# Predicted class for 19.jpg : benign
# Class probability: 0.9999995
# Predicted class for 20.jpg : benign
# Class probability: 0.9499863
# Predicted class for 21.jpg : benign
# Class probability: 0.75175005
# Predicted class for 22.jpg : benign
# Class probability: 0.7027521
# Predicted class for 23.jpg : benign
# Class probability: 0.99999964
# Predicted class for 24.jpg : benign
# Class probability: 0.9187769
# Predicted class for 25.jpg : malignant
# Class probability: 0.9688036
# Predicted class for 26.jpg : benign
# Class probability: 0.52860963
# Predicted class for 27.jpg : benign
# Class probability: 0.9996788
# Predicted class for 28.jpg : benign
# Class probability: 0.9992304
# Predicted class for 29.jpg : benign
# Class probability: 0.5344159
# Predicted class for 30.jpg : benign
# Class probability: 0.9999995
# Predicted class for 31.jpg : malignant
# Class probability: 0.6795867
# Predicted class for 32.jpg : malignant
# Class probability: 0.96185327
# Predicted class for 33.jpg : benign
# Class probability: 0.98459935
# Predicted class for 34.jpg : benign
# Class probability: 0.9987679
# Predicted class for 35.jpg : benign
# Class probability: 0.9999896
# Predicted class for 36.jpg : benign
# Class probability: 0.9852341
# Predicted class for 37.jpg : benign
# Class probability: 0.99941325
# Predicted class for 38.jpg : benign
# Class probability: 0.9894391
# Predicted class for 39.jpg : malignant
# Class probability: 0.70706284
# Predicted class for 40.jpg : benign
# Class probability: 0.99986625
# Predicted class for 41.jpg : benign
# Class probability: 0.7373593
# Predicted class for 42.jpg : benign
# Class probability: 0.9873663
# Predicted class for 43.jpg : benign
# Class probability: 0.9965927
# Predicted class for 44.jpg : benign
# Class probability: 0.95607686
# Predicted class for 45.jpg : benign
# Class probability: 0.7931399
# Predicted class for 46.jpg : benign
# Class probability: 0.8871206
# Predicted class for 47.jpg : benign
# Class probability: 0.87022674
# Predicted class for 48.jpg : benign
# Class probability: 0.99996567
# Predicted class for 49.jpg : benign
# Class probability: 0.9999833
# Predicted class for 50.jpg : malignant
# Class probability: 0.61176765
# Predicted class for 51.jpg : benign
# Class probability: 0.998766
# Predicted class for 52.jpg : benign
# Class probability: 0.9975827
# Predicted class for 53.jpg : benign
# Class probability: 0.99996793
# Predicted class for 54.jpg : benign
# Class probability: 0.999923
# Predicted class for 55.jpg : benign
# Class probability: 0.9989367
# Predicted class for 56.jpg : benign
# Class probability: 0.99997747
# Predicted class for 57.jpg : malignant
# Class probability: 0.6218619
# Predicted class for 58.jpg : benign
# Class probability: 0.99994445
# Predicted class for 59.jpg : benign
# Class probability: 0.9999492
# Predicted class for 60.jpg : benign
# Class probability: 0.65721816
# Predicted class for 61.jpg : benign
# Class probability: 0.9935817
# Predicted class for 62.jpg : benign
# Class probability: 0.7023088
# Predicted class for 63.jpg : benign
# Class probability: 0.99944144
# Predicted class for 64.jpg : benign
# Class probability: 0.9997472
# Predicted class for 65.jpg : benign
# Class probability: 0.9831114
# Predicted class for 66.jpg : benign
# Class probability: 0.9999746
# Predicted class for 67.jpg : benign
# Class probability: 0.999827
# Predicted class for 68.jpg : benign
# Class probability: 0.9985501
# Predicted class for 69.jpg : benign
# Class probability: 0.9482989
# Predicted class for 70.jpg : malignant
# Class probability: 0.9380773
# Predicted class for 71.jpg : benign
# Class probability: 0.9999889
# Predicted class for 72.jpg : benign
# Class probability: 0.9960407
# Predicted class for 73.jpg : benign
# Class probability: 0.9925409
# Predicted class for 74.jpg : benign
# Class probability: 0.9293497
# Predicted class for 75.jpg : benign
# Class probability: 0.99724644
# Predicted class for 76.jpg : benign
# Class probability: 0.9999589
# Predicted class for 77.jpg : benign
# Class probability: 0.99969286
# Predicted class for 78.jpg : benign
# Class probability: 0.99975115
# Predicted class for 79.jpg : benign
# Class probability: 0.9901609
# Predicted class for 80.jpg : benign
# Class probability: 0.9339577
# Predicted class for 81.jpg : malignant
# Class probability: 0.9121092
# Predicted class for 82.jpg : benign
# Class probability: 0.99982166
# Predicted class for 83.jpg : benign
# Class probability: 0.9987661
# Predicted class for 84.jpg : benign
# Class probability: 0.69036555
# Predicted class for 85.jpg : benign
# Class probability: 0.9999908
# Predicted class for 86.jpg : benign
# Class probability: 0.99999297
# Predicted class for 87.jpg : benign
# Class probability: 0.9725629
# Predicted class for 88.jpg : benign
# Class probability: 0.99958616
# Predicted class for 89.jpg : benign
# Class probability: 0.9727069
# Predicted class for 90.jpg : benign
# Class probability: 0.9979577
# Predicted class for 91.jpg : benign
# Class probability: 0.999982
# Predicted class for 92.jpg : benign
# Class probability: 0.99767345
# Predicted class for 93.jpg : benign
# Class probability: 0.9998622
# Predicted class for 94.jpg : malignant
# Class probability: 0.90093535
# Predicted class for 95.jpg : benign
# Class probability: 0.99864453
# Predicted class for 96.jpg : benign
# Class probability: 0.94074047
# Predicted class for 97.jpg : malignant
# Class probability: 0.73255223
# Predicted class for 98.jpg : benign
# Class probability: 0.563138
# Predicted class for 99.jpg : benign
# Class probability: 0.9700116
# Predicted class for 100.jpg : benign
# Class probability: 0.99945086
# Predicted class for 101.jpg : benign
# Class probability: 0.9998505
# Predicted class for 102.jpg : malignant
# Class probability: 0.57547486
# Predicted class for 103.jpg : benign
# Class probability: 0.98950833
# Predicted class for 104.jpg : benign
# Class probability: 0.760381
# Predicted class for 105.jpg : benign
# Class probability: 0.99849534
# Predicted class for 106.jpg : benign
# Class probability: 0.99422705
# Predicted class for 107.jpg : benign
# Class probability: 0.99916005
# Predicted class for 108.jpg : benign
# Class probability: 0.99976546
# Predicted class for 109.jpg : benign
# Class probability: 0.9988366
# Predicted class for 110.jpg : malignant
# Class probability: 0.65141314
# Predicted class for 111.jpg : benign
# Class probability: 0.57604
# Predicted class for 112.jpg : benign
# Class probability: 0.9963509
# Predicted class for 113.jpg : benign
# Class probability: 0.99985886
# Predicted class for 114.jpg : malignant
# Class probability: 0.5953666
# Predicted class for 115.jpg : benign
# Class probability: 0.9989365
# Predicted class for 116.jpg : benign
# Class probability: 0.9992415
# Predicted class for 117.jpg : benign
# Class probability: 0.7568733
# Predicted class for 118.jpg : benign
# Class probability: 0.9997427
# Predicted class for 119.jpg : benign
# Class probability: 0.9976289
# Predicted class for 120.jpg : benign
# Class probability: 0.9990638
# Predicted class for 121.jpg : malignant
# Class probability: 0.91003424
# Predicted class for 122.jpg : benign
# Class probability: 0.9999846
# Predicted class for 123.jpg : benign
# Class probability: 0.9998133
# Predicted class for 124.jpg : benign
# Class probability: 0.9999459
# Predicted class for 125.jpg : benign
# Class probability: 0.99996054
# Predicted class for 126.jpg : benign
# Class probability: 0.9998841
# Predicted class for 127.jpg : benign
# Class probability: 0.99950933
# Predicted class for 128.jpg : benign
# Class probability: 0.99965703
# Predicted class for 129.jpg : benign
# Class probability: 0.99998784
# Predicted class for 130.jpg : benign
# Class probability: 0.99900997
# Predicted class for 131.jpg : malignant
# Class probability: 0.6331569
# Predicted class for 132.jpg : benign
# Class probability: 0.99962413
# Predicted class for 133.jpg : malignant
# Class probability: 0.8320392
# Predicted class for 134.jpg : benign
# Class probability: 0.9710853
# Predicted class for 135.jpg : benign
# Class probability: 0.7882284
# Predicted class for 136.jpg : benign
# Class probability: 0.99993634
# Predicted class for 137.jpg : benign
# Class probability: 0.99999547
# Predicted class for 138.jpg : benign
# Class probability: 0.99998903
# Predicted class for 139.jpg : benign
# Class probability: 0.9979652
# Predicted class for 140.jpg : benign
# Class probability: 0.98935974
# Predicted class for 141.jpg : benign
# Class probability: 0.9991641
# Predicted class for 142.jpg : benign
# Class probability: 0.7679633
# Predicted class for 143.jpg : benign
# Class probability: 0.95606697
# Predicted class for 144.jpg : benign
# Class probability: 0.9962504
# Predicted class for 145.jpg : benign
# Class probability: 0.9999981
# Predicted class for 146.jpg : benign
# Class probability: 0.999672
# Predicted class for 147.jpg : benign
# Class probability: 0.5107693
# Predicted class for 148.jpg : benign
# Class probability: 0.8322046
# Predicted class for 149.jpg : benign
# Class probability: 0.71159244
# Predicted class for 150.jpg : benign
# Class probability: 0.9999999
# Predicted class for 151.jpg : benign
# Class probability: 0.8635534
# Predicted class for 152.jpg : benign
# Class probability: 0.999995
# Predicted class for 153.jpg : malignant
# Class probability: 0.9077178
# Predicted class for 154.jpg : benign
# Class probability: 0.99998474
# Predicted class for 155.jpg : malignant
# Class probability: 0.9891356
# Predicted class for 156.jpg : benign
# Class probability: 0.9999336
# Predicted class for 157.jpg : benign
# Class probability: 0.99716276
# Predicted class for 158.jpg : benign
# Class probability: 0.9999621
# Predicted class for 159.jpg : malignant
# Class probability: 0.6609488
# Predicted class for 160.jpg : benign
# Class probability: 0.64496905
# Predicted class for 161.jpg : benign
# Class probability: 0.9998759
# Predicted class for 162.jpg : benign
# Class probability: 0.99962556
# Predicted class for 163.jpg : benign
# Class probability: 0.90846777
# Predicted class for 164.jpg : benign
# Class probability: 0.6304492
# Predicted class for 165.jpg : benign
# Class probability: 0.99995506
# Predicted class for 166.jpg : benign
# Class probability: 0.9999981
# Predicted class for 167.jpg : benign
# Class probability: 0.99990284
# Predicted class for 168.jpg : benign
# Class probability: 0.9869537
# Predicted class for 169.jpg : malignant
# Class probability: 0.9148004
# Predicted class for 170.jpg : benign
# Class probability: 0.8960042
# Predicted class for 171.jpg : malignant
# Class probability: 0.97924584
# Predicted class for 172.jpg : malignant
# Class probability: 0.93039274
# Predicted class for 173.jpg : benign
# Class probability: 0.84713966
# Predicted class for 174.jpg : benign
# Class probability: 0.7940483
# Predicted class for 175.jpg : malignant
# Class probability: 0.91516584
# Predicted class for 176.jpg : benign
# Class probability: 0.942061
# Predicted class for 177.jpg : benign
# Class probability: 0.9993992
# Predicted class for 178.jpg : malignant
# Class probability: 0.5291917
# Predicted class for 179.jpg : malignant
# Class probability: 0.6812648
# Predicted class for 180.jpg : benign
# Class probability: 0.98721534
# Predicted class for 181.jpg : benign
# Class probability: 0.9999999
# Predicted class for 182.jpg : benign
# Class probability: 0.9999999
# Predicted class for 183.jpg : benign
# Class probability: 0.9999827
# Predicted class for 184.jpg : benign
# Class probability: 0.99936336
# Predicted class for 185.jpg : malignant
# Class probability: 0.79482335
# Predicted class for 186.jpg : benign
# Class probability: 0.87651306
# Predicted class for 187.jpg : benign
# Class probability: 0.999635
# Predicted class for 188.jpg : benign
# Class probability: 0.99965525
# Predicted class for 189.jpg : benign
# Class probability: 0.9443667
# Predicted class for 190.jpg : malignant
# Class probability: 0.8311886
# Predicted class for 191.jpg : benign
# Class probability: 0.998774
# Predicted class for 192.jpg : malignant
# Class probability: 0.5518839
# Predicted class for 193.jpg : benign
# Class probability: 0.99957365
# Predicted class for 194.jpg : benign
# Class probability: 0.9752725
# Predicted class for 195.jpg : benign
# Class probability: 0.9990483
# Predicted class for 196.jpg : benign
# Class probability: 0.9997335
# Predicted class for 197.jpg : malignant
# Class probability: 0.9181463
# Predicted class for 198.jpg : benign
# Class probability: 0.99974555
# Predicted class for 199.jpg : benign
# Class probability: 0.99994576
# Predicted class for 200.jpg : benign
# Class probability: 0.9138396
# Predicted class for 201.jpg : benign
# Class probability: 0.9961044
# Predicted class for 202.jpg : benign
# Class probability: 0.9996787
# Predicted class for 203.jpg : benign
# Class probability: 0.9999672
# Predicted class for 204.jpg : malignant
# Class probability: 0.85096234
# Predicted class for 205.jpg : malignant
# Class probability: 0.60623205
# Predicted class for 206.jpg : benign
# Class probability: 0.91644603
# Predicted class for 207.jpg : benign
# Class probability: 0.99975234
# Predicted class for 208.jpg : benign
# Class probability: 0.9999908
# Predicted class for 209.jpg : benign
# Class probability: 0.6893107
# Predicted class for 210.jpg : benign
# Class probability: 0.9968906
# Predicted class for 211.jpg : benign
# Class probability: 0.99995863
# Predicted class for 212.jpg : benign
# Class probability: 0.86689204
# Predicted class for 213.jpg : benign
# Class probability: 0.99999917
# Predicted class for 214.jpg : benign
# Class probability: 0.9966671
# Predicted class for 215.jpg : benign
# Class probability: 0.8527368
# Predicted class for 216.jpg : benign
# Class probability: 0.99341196
# Predicted class for 217.jpg : benign
# Class probability: 0.8546527
# Predicted class for 218.jpg : benign
# Class probability: 0.97808516
# Predicted class for 219.jpg : benign
# Class probability: 0.98759043
# Predicted class for 220.jpg : benign
# Class probability: 0.999135
# Predicted class for 221.jpg : benign
# Class probability: 0.8348578
# Predicted class for 222.jpg : benign
# Class probability: 0.9999417
# Predicted class for 223.jpg : benign
# Class probability: 0.9999219
# Predicted class for 224.jpg : benign
# Class probability: 0.9994522
# Predicted class for 225.jpg : benign
# Class probability: 0.99981415
# Predicted class for 226.jpg : benign
# Class probability: 0.99999523
# Predicted class for 227.jpg : benign
# Class probability: 0.8565369
# Predicted class for 228.jpg : benign
# Class probability: 0.9999676
# Predicted class for 229.jpg : benign
# Class probability: 0.92146355
# Predicted class for 230.jpg : benign
# Class probability: 0.8687634
# Predicted class for 231.jpg : benign
# Class probability: 0.9983405
# Predicted class for 232.jpg : benign
# Class probability: 0.7229427
# Predicted class for 233.jpg : benign
# Class probability: 0.99982727
# Predicted class for 234.jpg : benign
# Class probability: 0.8602398
# Predicted class for 235.jpg : benign
# Class probability: 0.57821196
# Predicted class for 236.jpg : benign
# Class probability: 0.9997644
# Predicted class for 237.jpg : benign
# Class probability: 0.9980209
# Predicted class for 238.jpg : benign
# Class probability: 0.51946336
# Predicted class for 239.jpg : benign
# Class probability: 0.9999939
# Predicted class for 240.jpg : benign
# Class probability: 0.8193291
# Predicted class for 241.jpg : benign
# Class probability: 0.99867034
# Predicted class for 242.jpg : benign
# Class probability: 0.99995315
# Predicted class for 243.jpg : benign
# Class probability: 0.99991703
# Predicted class for 244.jpg : malignant
# Class probability: 0.65763235
# Predicted class for 245.jpg : benign
# Class probability: 0.85473466
# Predicted class for 246.jpg : benign
# Class probability: 0.9997248
# Predicted class for 247.jpg : benign
# Class probability: 0.99997723
# Predicted class for 248.jpg : benign
# Class probability: 0.99997675
# Predicted class for 249.jpg : benign
# Class probability: 0.99941987
# Predicted class for 250.jpg : benign
# Class probability: 0.9610822
# Predicted class for 251.jpg : benign
# Class probability: 0.99995625
# Predicted class for 252.jpg : benign
# Class probability: 0.96044403
# Predicted class for 253.jpg : benign
# Class probability: 0.6908405
# Predicted class for 254.jpg : benign
# Class probability: 0.64765733
# Predicted class for 255.jpg : benign
# Class probability: 0.6678537
# Predicted class for 256.jpg : benign
# Class probability: 0.99999464
# Predicted class for 257.jpg : benign
# Class probability: 0.9979492
# Predicted class for 258.jpg : benign
# Class probability: 0.540255
# Predicted class for 259.jpg : malignant
# Class probability: 0.6359715
# Predicted class for 260.jpg : benign
# Class probability: 0.6761381
# Predicted class for 261.jpg : benign
# Class probability: 0.78801507
# Predicted class for 262.jpg : benign
# Class probability: 0.99997985
# Predicted class for 263.jpg : benign
# Class probability: 0.99376184
# Predicted class for 264.jpg : benign
# Class probability: 0.9989557
# Predicted class for 265.jpg : benign
# Class probability: 0.9999926
# Predicted class for 266.jpg : benign
# Class probability: 0.75197583
# Predicted class for 267.jpg : benign
# Class probability: 0.8760459
# Predicted class for 268.jpg : benign
# Class probability: 0.9974928
# Predicted class for 269.jpg : benign
# Class probability: 0.97674656
# Predicted class for 270.jpg : benign
# Class probability: 0.99802184
# Predicted class for 271.jpg : benign
# Class probability: 0.9999989
# Predicted class for 272.jpg : benign
# Class probability: 0.85285956
# Predicted class for 273.jpg : benign
# Class probability: 0.87652206
# Predicted class for 274.jpg : benign
# Class probability: 0.9866723
# Predicted class for 275.jpg : benign
# Class probability: 0.7814483
# Predicted class for 276.jpg : benign
# Class probability: 0.99978197
# Predicted class for 277.jpg : malignant
# Class probability: 0.5392694
# Predicted class for 278.jpg : benign
# Class probability: 0.99950504
# Predicted class for 279.jpg : benign
# Class probability: 0.7914807
# Predicted class for 280.jpg : benign
# Class probability: 0.9998796
# Predicted class for 281.jpg : benign
# Class probability: 0.990328
# Predicted class for 282.jpg : benign
# Class probability: 0.99992347
# Predicted class for 283.jpg : malignant
# Class probability: 0.70464045
# Predicted class for 284.jpg : malignant
# Class probability: 0.747798
# Predicted class for 285.jpg : benign
# Class probability: 0.975476
# Predicted class for 286.jpg : benign
# Class probability: 0.9951384
# Predicted class for 287.jpg : benign
# Class probability: 0.99993026
# Predicted class for 288.jpg : benign
# Class probability: 0.8871065
# Predicted class for 289.jpg : benign
# Class probability: 0.86886245
# Predicted class for 290.jpg : benign
# Class probability: 0.9999888
# Predicted class for 291.jpg : benign
# Class probability: 0.99956983
# Predicted class for 292.jpg : benign
# Class probability: 0.99898666
# Predicted class for 293.jpg : benign
# Class probability: 0.9998255
# Predicted class for 294.jpg : benign
# Class probability: 0.9593197
# Predicted class for 295.jpg : benign
# Class probability: 0.9998629
# Predicted class for 296.jpg : benign
# Class probability: 0.77746135
# Predicted class for 297.jpg : benign
# Class probability: 0.9999994
# Predicted class for 298.jpg : benign
# Class probability: 0.9980719
# Predicted class for 299.jpg : benign
# Class probability: 0.94114965
# Predicted class for 300.jpg : benign
# Class probability: 0.9994683
# Predicted class for 301.jpg : benign
# Class probability: 0.9999784
# Predicted class for 302.jpg : benign
# Class probability: 0.99998116
# Predicted class for 303.jpg : benign
# Class probability: 0.9930432
# Predicted class for 304.jpg : benign
# Class probability: 0.9967642
# Predicted class for 305.jpg : malignant
# Class probability: 0.9926293
# Predicted class for 306.jpg : benign
# Class probability: 0.5487702
# Predicted class for 307.jpg : benign
# Class probability: 0.99849844
# Predicted class for 308.jpg : malignant
# Class probability: 0.775219
# Predicted class for 309.jpg : benign
# Class probability: 0.6963552
# Predicted class for 310.jpg : benign
# Class probability: 0.99947727
# Predicted class for 311.jpg : benign
# Class probability: 0.9999906
# Predicted class for 312.jpg : benign
# Class probability: 0.9999994
# Predicted class for 313.jpg : benign
# Class probability: 0.6538638
# Predicted class for 314.jpg : benign
# Class probability: 0.9213149
# Predicted class for 315.jpg : benign
# Class probability: 0.99989176
# Predicted class for 316.jpg : benign
# Class probability: 0.9994081
# Predicted class for 317.jpg : malignant
# Class probability: 0.60808784
# Predicted class for 318.jpg : benign
# Class probability: 0.7467637
# Predicted class for 319.jpg : benign
# Class probability: 0.52902925
# Predicted class for 320.jpg : benign
# Class probability: 0.813925
# Predicted class for 321.jpg : benign
# Class probability: 0.6871939
# Predicted class for 322.jpg : benign
# Class probability: 0.9999999
# Predicted class for 323.jpg : benign
# Class probability: 0.7847735
# Predicted class for 324.jpg : benign
# Class probability: 0.61420417
# Predicted class for 325.jpg : benign
# Class probability: 0.9986777
# Predicted class for 326.jpg : benign
# Class probability: 0.99321514
# Predicted class for 327.jpg : benign
# Class probability: 0.99974173
# Predicted class for 328.jpg : benign
# Class probability: 0.96763223
# Predicted class for 329.jpg : benign
# Class probability: 0.67454666
# Predicted class for 330.jpg : malignant
# Class probability: 0.7924293
# Predicted class for 331.jpg : benign
# Class probability: 0.9998429
# Predicted class for 332.jpg : benign
# Class probability: 0.98554146
# Predicted class for 333.jpg : benign
# Class probability: 0.99999905
# Predicted class for 334.jpg : benign
# Class probability: 0.9999975
# Predicted class for 335.jpg : benign
# Class probability: 0.8376897
# Predicted class for 336.jpg : benign
# Class probability: 0.99995506
# Predicted class for 337.jpg : benign
# Class probability: 0.9965842
# Predicted class for 338.jpg : malignant
# Class probability: 0.8479793
# Predicted class for 339.jpg : benign
# Class probability: 0.9997303
# Predicted class for 340.jpg : benign
# Class probability: 0.99322355
# Predicted class for 341.jpg : benign
# Class probability: 0.9937487
# Predicted class for 342.jpg : benign
# Class probability: 0.9999989
# Predicted class for 343.jpg : benign
# Class probability: 0.9328826
# Predicted class for 344.jpg : benign
# Class probability: 0.6560946
# Predicted class for 345.jpg : benign
# Class probability: 0.9997827
# Predicted class for 346.jpg : benign
# Class probability: 0.9514313
# Predicted class for 347.jpg : benign
# Class probability: 0.9995846
# Predicted class for 348.jpg : benign
# Class probability: 0.8903372
# Predicted class for 349.jpg : benign
# Class probability: 0.5887863
# Predicted class for 350.jpg : benign
# Class probability: 0.98839915
# Predicted class for 351.jpg : benign
# Class probability: 0.9999795
# Predicted class for 352.jpg : benign
# Class probability: 0.9998143
# Predicted class for 353.jpg : benign
# Class probability: 0.99985147
# Predicted class for 354.jpg : benign
# Class probability: 0.5834581
# Predicted class for 355.jpg : benign
# Class probability: 0.6825541
# Predicted class for 356.jpg : benign
# Class probability: 0.52517784
# Predicted class for 357.jpg : malignant
# Class probability: 0.67853165
# Predicted class for 358.jpg : benign
# Class probability: 0.8944207
# Predicted class for 359.jpg : benign
# Class probability: 0.53252137
# Predicted class for 360.jpg : benign
# Class probability: 0.9998064
