# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, GlobalAveragePooling2D, Dropout, Flatten
from tensorflow.keras.applications import VGG19
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_ds="/content/drive/MyDrive/datasetskincancer/data/train"
test_ds="/content/drive/MyDrive/datasetskincancer/data/test"

# %% [markdown]
# # Data preprocessing
# ****

# %%
os.listdir('/content/drive/MyDrive/datasetskincancer/data/train')
# Out:
# ['benign', 'malignant']

# %%
batch_size=32
img_size=224

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,
                             zoom_range=0.2,
                            width_shift_range=0.2,height_shift_range=0.2
                             )

test_datagen = ImageDataGenerator(rescale=1/255.)

train_generator = train_datagen.flow_from_directory(train_ds,
                                                target_size=(img_size, img_size),
                                                batch_size=batch_size,
                                                shuffle=True,
                                                class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_ds,
                                                    target_size=(img_size, img_size),
                                                    batch_size=batch_size,
                                                    shuffle=False,
                                                    class_mode='categorical')
# Out:
# Found 2637 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.

# %%
labels = [k for k in train_generator.class_indices]
sample_generate = train_generator.__next__()

images = sample_generate[0]
titles = sample_generate[1]
plt.figure(figsize = (20 , 20))

for i in range(15):
    plt.subplot(5 , 5, i+1)
    plt.subplots_adjust(hspace = 0.3 , wspace = 0.3)
    plt.imshow(images[i])
    plt.title(f'Class: {labels[np.argmax(titles[i],axis=0)]}')
    plt.axis("off")

# %%
print(len(train_generator))
print(len(test_ds))
# Out:
# 83
# 50

# %%
import matplotlib.pyplot as plt
from skimage import io

# Load image
img_url = "/content/drive/MyDrive/datasetskincancer/data/train/benign/1001.jpg"
img = io.imread(img_url)

# Display image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from keras.layers import MaxPool2D

# %%
import numpy as np
from keras.layers import Dense,Flatten,Conv2D,Activation,Dropout

from keras import backend as K

import keras

from keras.models import Sequential, Model

from keras.models import load_model

from keras.optimizers import SGD

from keras.callbacks import EarlyStopping,ModelCheckpoint

from keras.layers import MaxPool2D

# %% [markdown]
# # Build VGG_19 Model

# %%
from keras.layers import MaxPool2D

# %%
from keras.layers import MaxPool2D

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
# Define input shape
input_shape = (img_size, img_size, 3)

# Create a Sequential model
model = Sequential([
    Input(shape=input_shape),  # Specify input shape in the first layer
    Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=64, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=128, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=256, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    Conv2D(filters=512, kernel_size=(3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Flatten(),
    Dense(units=4096, activation="relu"),
    Dense(units=4096, activation="relu"),
    Dense(units=2, activation="softmax")
])

# %% [markdown]
# #   Model summary

# %%
# Print the model summary

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 4096)                │     102,764,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │           8,194 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 139,578,434 (532.45 MB)
#  Trainable params: 139,578,434 (532.45 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.optimizers import Adam
opt = Adam(learning_rate=0.00001)
model.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])

# %%
history = model.fit(train_generator,
                    epochs=100,
                    validation_data=test_generator)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 444s 5s/step - accuracy: 0.5418 - loss: 0.6838 - val_accuracy: 0.7636 - val_loss: 0.4821
# Epoch 2/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 65s 742ms/step - accuracy: 0.4982 - loss: 0.6813 - val_accuracy: 0.5455 - val_loss: 0.6923
# Epoch 3/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 743ms/step - accuracy: 0.5753 - loss: 0.6791 - val_accuracy: 0.7652 - val_loss: 0.4758
# Epoch 4/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 749ms/step - accuracy: 0.7595 - loss: 0.4837 - val_accuracy: 0.7742 - val_loss: 0.4465
# Epoch 5/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 65s 724ms/step - accuracy: 0.7802 - loss: 0.4463 - val_accuracy: 0.7924 - val_loss: 0.4216
# Epoch 6/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 64s
100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 65s 742ms/step - accuracy: 0.9134 - loss: 0.1960 - val_accuracy: 0.8788 - val_loss: 0.3452
# Epoch 89/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 63s 722ms/step - accuracy: 0.9043 - loss: 0.2181 - val_accuracy: 0.8818 - val_loss: 0.2988
# Epoch 90/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 84s 751ms/step - accuracy: 0.9008 - loss: 0.2085 - val_accuracy: 0.8545 - val_loss: 0.3287
# Epoch 91/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 737ms/step - accuracy: 0.9051 - loss: 0.2122 - val_accuracy: 0.8803 - val_loss: 0.2981
# Epoch 92/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 66s 753ms/step - accuracy: 0.9180 - loss: 0.1946 - val_accuracy: 0.8742 - val_loss: 0.3213
# Epoch 93/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 751ms/step - accuracy: 0.9171 - loss: 0.1957 - val_accuracy: 0.8773 - val_loss: 0.3000
# Epoch 94/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 759ms/step - accuracy: 0.9214 - loss: 0.1928 - val_accuracy: 0.8606 - val_loss: 0.3193
# Epoch 95/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 773ms/step - accuracy: 0.9214 - loss: 0.1958 - val_accuracy: 0.8712 - val_loss: 0.3055
# Epoch 96/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 79s 733ms/step - accuracy: 0.9056 - loss: 0.2293 - val_accuracy: 0.8727 - val_loss: 0.3078
# Epoch 97/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 738ms/step - accuracy: 0.9131 - loss: 0.1961 - val_accuracy: 0.8697 - val_loss: 0.3526
# Epoch 98/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 83s 749ms/step - accuracy: 0.9228 - loss: 0.1849 - val_accuracy: 0.8742 - val_loss: 0.3438
# Epoch 99/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 80s 732ms/step - accuracy: 0.9230 - loss: 0.1831 - val_accuracy: 0.8727 - val_loss: 0.3034
# Epoch 100/100
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 64s 712ms/step - accuracy: 0.9236 - loss: 0.1730 - val_accuracy: 0.8758 - val_loss: 0.3350

# %%
n_categories = len(os.listdir('/content/drive/MyDrive/datasetskincancer/test'))# number of categories print(n_categories)

# %%
n_categories
# Out:
# 2

# %%
results =pd.DataFrame(history.history)
results.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.569966  0.659757      0.763636  0.482103
# 1  0.496397  0.692899      0.545455  0.692275
# 2  0.644672  0.632456      0.765152  0.475782
# 3  0.767918  0.475562      0.774242  0.446516
# 4  0.786879  0.437178      0.792424  0.421650

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['Train','Val'], loc= 'upper left')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
y_test_1 = test_generator.classes
y_pred_1 =model.predict(test_generator)
y_pred_1 = np.argmax(y_pred_1,axis=1)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step

# %%
results =model.evaluate(test_generator)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.8740 - loss: 0.3402

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix,precision_score, recall_score, roc_curve, f1_score

print(classification_report(y_test_1, y_pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89       360
#            1       0.86      0.87      0.86       300
#
#     accuracy                           0.88       660
#    macro avg       0.87      0.88      0.87       660
# weighted avg       0.88      0.88      0.88       660

# %%
# Calculate metrics for each class
precision_0 = precision_score(y_test_1, y_pred_1, pos_label=0)
recall_0 = recall_score(y_test_1, y_pred_1, pos_label=0)
f1_0 = f1_score(y_test_1, y_pred_1, pos_label=0)
precision_1 = precision_score(y_test_1, y_pred_1, pos_label=1)
recall_1 = recall_score(y_test_1, y_pred_1, pos_label=1)
f1_1 = f1_score(y_test_1, y_pred_1, pos_label=1)

# %%
# Calculate additional metrics
auc = roc_auc_score(y_test_1, y_pred_1)
tn, fp, fn, tp = confusion_matrix(y_test_1, y_pred_1).ravel()
precision = precision_score(y_test_1, y_pred_1)
recall = recall_score(y_test_1, y_pred_1)
specificity = tn / (tn + fp)
fdr = fp / (fp + tp)
fnr = fn / (fn + tp)
fpr = fp / (fp + tn)



# Print additional metrics for each class
print("Additional Metrics for Class 0:")
print(f"Precision: {precision_0:.2f}")
print(f"Recall: {recall_0:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"F1 Score: {f1_0:.2f}")
print(f"FDR: {fdr:.2f}")
print(f"FNR: {fnr:.2f}")
print(f"FPR: {fpr:.2f}\n")

print("Additional Metrics for Class 1:")
print(f"Precision: {precision_1:.2f}")
print(f"Recall: {recall_1:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"F1 Score: {f1_1:.2f}")
print(f"FDR: {fdr:.2f}")
print(f"FNR: {fnr:.2f}")
print(f"FPR: {fpr:.2f}\n")

# Print average metrics
precision_avg = (precision_0 + precision_1) / 2
recall_avg = (recall_0 + recall_1) / 2
f1_avg = (f1_0 + f1_1) / 2

print("Average Metrics:")
print(f"Precision: {precision_avg:.2f}")
print(f"Recall: {recall_avg:.2f}")
print(f"F1 Score: {f1_avg:.2f}")
print(f"AUC: {auc:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"FDR: {fdr:.2f}")
print(f"FNR: {fnr:.2f}")
print(f"FPR: {fpr:.2f}")
# Out:
# Additional Metrics for Class 0:
# Precision: 0.89
# Recall: 0.88
# Specificity: 0.88
# F1 Score: 0.89
# FDR: 0.14
# FNR: 0.13
# FPR: 0.12
#
# Additional Metrics for Class 1:
# Precision: 0.86
# Recall: 0.87
# Specificity: 0.88
# F1 Score: 0.86
# FDR: 0.14
# FNR: 0.13
# FPR: 0.12
#
# Average Metrics:
# Precision: 0.87
# Recall: 0.88
# F1 Score: 0.87
# AUC: 0.88
# Specificity: 0.88
# FDR: 0.14
# FNR: 0.13
# FPR: 0.12

# %%
import matplotlib.pyplot as plt
# Calculate ROC curve
fpr_values, tpr_values, _ = roc_curve(y_test_1, y_pred_1)

# Plot ROC curve
plt.figure()
plt.plot(fpr_values, tpr_values, color='darkorange', lw=2, label=f'ROC curve (area = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt

image_directory = '/content/drive/MyDrive/datasetskincancer/data/test/benign'
img_size = 224

images = []
for filename in os.listdir(image_directory):
    path = os.path.join(image_directory, filename)
    img = Image.open(path)
    img = img.resize((img_size, img_size))
    images.append(img)

images = np.array([np.array(img) for img in images])
images = images / 255.0

predictions = model.predict(images)

# Select image to display
img_index = 0

# Get predicted class label
class_label = np.argmax(predictions[img_index])

# Display image and predicted class label
plt.imshow(images[img_index])
plt.axis('off')
plt.title('Predicted class: ' + str(class_label))
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 621ms/step

# %%
for i in range(len(images)):
    predicted_class = np.argmax(predictions[i])
    class_probability = predictions[i, predicted_class]
    print(f'Predicted class for {i+1}.jpg : {labels[predicted_class]}')
    print('Class probability:', class_probability)
# Out:
# Predicted class for 1.jpg : benign
# Class probability: 0.7382144
# Predicted class for 2.jpg : benign
# Class probability: 1.0
# Predicted class for 3.jpg : benign
# Class probability: 1.0
# Predicted class for 4.jpg : benign
# Class probability: 0.5727667
# Predicted class for 5.jpg : benign
# Class probability: 0.99984634
# Predicted class for 6.jpg : benign
# Class probability: 1.0
# Predicted class for 7.jpg : malignant
# Class probability: 0.7934157
# Predicted class for 8.jpg : benign
# Class probability: 0.99999404
# Predicted class for 9.jpg : benign
# Class probability: 0.9407098
# Predicted class for 10.jpg : benign
# Class probability: 0.6258424
# Predicted class for 11.jpg : benign
# Class probability: 0.5829303
# Predicted class for 12.jpg : benign
# Class probability: 1.0
# Predicted class for 13.jpg : benign
# Class probability: 0.9744192
# Predicted class for 14.jpg : benign
# Class probability: 1.0
# Predicted class for 15.jpg : benign
# Class probability: 0.7176147
# Predicted class for 16.jpg : benign
# Class probability: 0.96843976
# Predicted class for 17.jpg : benign
# Class probability: 0.9966773
# Predicted class for 18.jpg : benign
# Class probability: 0.7389372
# Predicted class for 19.jpg : benign
# Class probability: 0.9999732
# Predicted class for 20.jpg : benign
# Class probability: 0.87762845
# Predicted class for 21.jpg : benign
# Class probability: 0.99999857
# Predicted class for 22.jpg : benign
# Class probability: 0.9934163
# Predicted class for 23.jpg : malignant
# Class probability: 0.9950212
# Predicted class for 24.jpg : malignant
# Class probability: 0.88736856
# Predicted class for 25.jpg : benign
# Class probability: 0.9999913
# Predicted class for 26.jpg : benign
# Class probability: 1.0
# Predicted class for 27.jpg : benign
# Class probability: 0.6269944
# Predicted class for 28.jpg : malignant
# Class probability: 0.72192705
# Predicted class for 29.jpg : benign
# Class probability: 0.99997723
# Predicted class for 30.jpg : benign
# Class probability: 0.9999888
# Predicted class for 31.jpg : benign
# Class probability: 0.9999995
# Predicted class for 32.jpg : malignant
# Class probability: 0.7216094
# Predicted class for 33.jpg : benign
# Class probability: 0.9995214
# Predicted class for 34.jpg : benign
# Class probability: 0.99915934
# Predicted class for 35.jpg : benign
# Class probability: 0.9999883
# Predicted class for 36.jpg : malignant
# Class probability: 0.7345289
# Predicted class for 37.jpg : benign
# Class probability: 0.59561676
# Predicted class for 38.jpg : benign
# Class probability: 0.99890554
# Predicted class for 39.jpg : benign
# Class probability: 0.99999666
# Predicted class for 40.jpg : benign
# Class probability: 0.9999976
# Predicted class for 41.jpg : benign
# Class probability: 0.8157797
# Predicted class for 42.jpg : benign
# Class probability: 0.99180835
# Predicted class for 43.jpg : benign
# Class probability: 0.99985874
# Predicted class for 44.jpg : benign
# Class probability: 0.940362
# Predicted class for 45.jpg : benign
# Class probability: 0.9121798
# Predicted class for 46.jpg : benign
# Class probability: 0.82743526
# Predicted class for 47.jpg : benign
# Class probability: 0.9967307
# Predicted class for 48.jpg : benign
# Class probability: 1.0
# Predicted class for 49.jpg : benign
# Class probability: 0.9999981
# Predicted class for 50.jpg : benign
# Class probability: 0.55852765
# Predicted class for 51.jpg : benign
# Class probability: 0.99999917
# Predicted class for 52.jpg : benign
# Class probability: 0.9999999
# Predicted class for 53.jpg : benign
# Class probability: 0.9999616
# Predicted class for 54.jpg : benign
# Class probability: 0.9999995
# Predicted class for 55.jpg : benign
# Class probability: 1.0
# Predicted class for 56.jpg : benign
# Class probability: 0.999998
# Predicted class for 57.jpg : benign
# Class probability: 0.99999976
# Predicted class for 58.jpg : benign
# Class probability: 0.6925589
# Predicted class for 59.jpg : benign
# Class probability: 1.0
# Predicted class for 60.jpg : benign
# Class probability: 0.96714664
# Predicted class for 61.jpg : benign
# Class probability: 0.9999968
# Predicted class for 62.jpg : benign
# Class probability: 0.9999875
# Predicted class for 63.jpg : malignant
# Class probability: 0.8772039
# Predicted class for 64.jpg : benign
# Class probability: 0.9999999
# Predicted class for 65.jpg : benign
# Class probability: 0.9999616
# Predicted class for 66.jpg : benign
# Class probability: 1.0
# Predicted class for 67.jpg : benign
# Class probability: 0.9999894
# Predicted class for 68.jpg : benign
# Class probability: 0.9999044
# Predicted class for 69.jpg : benign
# Class probability: 1.0
# Predicted class for 70.jpg : benign
# Class probability: 0.8923041
# Predicted class for 71.jpg : malignant
# Class probability: 0.9497463
# Predicted class for 72.jpg : benign
# Class probability: 0.9998373
# Predicted class for 73.jpg : benign
# Class probability: 0.999606
# Predicted class for 74.jpg : benign
# Class probability: 0.9929559
# Predicted class for 75.jpg : benign
# Class probability: 0.79437906
# Predicted class for 76.jpg : benign
# Class probability: 0.9984478
# Predicted class for 77.jpg : benign
# Class probability: 0.53914344
# Predicted class for 78.jpg : benign
# Class probability: 1.0
# Predicted class for 79.jpg : benign
# Class probability: 0.9999914
# Predicted class for 80.jpg : benign
# Class probability: 0.99999344
# Predicted class for 81.jpg : benign
# Class probability: 0.86052275
# Predicted class for 82.jpg : benign
# Class probability: 0.9999883
# Predicted class for 83.jpg : benign
# Class probability: 0.999997
# Predicted class for 84.jpg : benign
# Class probability: 0.87169564
# Predicted class for 85.jpg : benign
# Class probability: 0.9999664
# Predicted class for 86.jpg : benign
# Class probability: 0.8576624
# Predicted class for 87.jpg : benign
# Class probability: 0.9999094
# Predicted class for 88.jpg : malignant
# Class probability: 0.93225574
# Predicted class for 89.jpg : benign
# Class probability: 0.5679294
# Predicted class for 90.jpg : benign
# Class probability: 0.99999917
# Predicted class for 91.jpg : benign
# Class probability: 0.7129579
# Predicted class for 92.jpg : benign
# Class probability: 0.9999994
# Predicted class for 93.jpg : benign
# Class probability: 0.9999999
# Predicted class for 94.jpg : malignant
# Class probability: 0.7030662
# Predicted class for 95.jpg : benign
# Class probability: 0.99976593
# Predicted class for 96.jpg : benign
# Class probability: 0.9999795
# Predicted class for 97.jpg : benign
# Class probability: 0.6019036
# Predicted class for 98.jpg : benign
# Class probability: 0.9999999
# Predicted class for 99.jpg : benign
# Class probability: 0.99998856
# Predicted class for 100.jpg : benign
# Class probability: 0.9999995
# Predicted class for 101.jpg : benign
# Class probability: 0.9182403
# Predicted class for 102.jpg : malignant
# Class probability: 0.509226
# Predicted class for 103.jpg : benign
# Class probability: 0.99995315
# Predicted class for 104.jpg : benign
# Class probability: 1.0
# Predicted class for 105.jpg : benign
# Class probability: 0.99999833
# Predicted class for 106.jpg : benign
# Class probability: 0.9999871
# Predicted class for 107.jpg : benign
# Class probability: 0.9999993
# Predicted class for 108.jpg : malignant
# Class probability: 0.8600673
# Predicted class for 109.jpg : malignant
# Class probability: 0.9742667
# Predicted class for 110.jpg : benign
# Class probability: 0.99999976
# Predicted class for 111.jpg : benign
# Class probability: 0.99996686
# Predicted class for 112.jpg : benign
# Class probability: 0.99973994
# Predicted class for 113.jpg : malignant
# Class probability: 0.9748643
# Predicted class for 114.jpg : malignant
# Class probability: 0.71301055
# Predicted class for 115.jpg : benign
# Class probability: 0.99999964
# Predicted class for 116.jpg : benign
# Class probability: 0.9996294
# Predicted class for 117.jpg : malignant
# Class probability: 0.9778905
# Predicted class for 118.jpg : benign
# Class probability: 0.66125584
# Predicted class for 119.jpg : malignant
# Class probability: 0.827455
# Predicted class for 120.jpg : benign
# Class probability: 1.0
# Predicted class for 121.jpg : benign
# Class probability: 1.0
# Predicted class for 122.jpg : benign
# Class probability: 0.976839
# Predicted class for 123.jpg : benign
# Class probability: 0.99999356
# Predicted class for 124.jpg : malignant
# Class probability: 0.8180923
# Predicted class for 125.jpg : malignant
# Class probability: 0.7692746
# Predicted class for 126.jpg : benign
# Class probability: 0.7190724
# Predicted class for 127.jpg : benign
# Class probability: 0.99999917
# Predicted class for 128.jpg : malignant
# Class probability: 0.5442629
# Predicted class for 129.jpg : benign
# Class probability: 1.0
# Predicted class for 130.jpg : benign
# Class probability: 0.77749705
# Predicted class for 131.jpg : benign
# Class probability: 1.0
# Predicted class for 132.jpg : benign
# Class probability: 0.9999989
# Predicted class for 133.jpg : benign
# Class probability: 0.99999964
# Predicted class for 134.jpg : benign
# Class probability: 0.999982
# Predicted class for 135.jpg : benign
# Class probability: 0.99999976
# Predicted class for 136.jpg : benign
# Class probability: 0.99997663
# Predicted class for 137.jpg : benign
# Class probability: 0.9999975
# Predicted class for 138.jpg : benign
# Class probability: 0.99980867
# Predicted class for 139.jpg : benign
# Class probability: 0.9999857
# Predicted class for 140.jpg : malignant
# Class probability: 0.88201636
# Predicted class for 141.jpg : benign
# Class probability: 1.0
# Predicted class for 142.jpg : benign
# Class probability: 0.99997103
# Predicted class for 143.jpg : benign
# Class probability: 0.9999939
# Predicted class for 144.jpg : benign
# Class probability: 0.97248554
# Predicted class for 145.jpg : benign
# Class probability: 0.8862532
# Predicted class for 146.jpg : benign
# Class probability: 0.8825195
# Predicted class for 147.jpg : benign
# Class probability: 0.77693695
# Predicted class for 148.jpg : benign
# Class probability: 0.9999994
# Predicted class for 149.jpg : benign
# Class probability: 0.9999937
# Predicted class for 150.jpg : benign
# Class probability: 0.99998724
# Predicted class for 151.jpg : benign
# Class probability: 0.8335222
# Predicted class for 152.jpg : benign
# Class probability: 1.0
# Predicted class for 153.jpg : benign
# Class probability: 0.9968573
# Predicted class for 154.jpg : benign
# Class probability: 1.0
# Predicted class for 155.jpg : benign
# Class probability: 0.99999976
# Predicted class for 156.jpg : benign
# Class probability: 0.9925504
# Predicted class for 157.jpg : benign
# Class probability: 1.0
# Predicted class for 158.jpg : malignant
# Class probability: 0.85789293
# Predicted class for 159.jpg : benign
# Class probability: 1.0
# Predicted class for 160.jpg : benign
# Class probability: 0.9999982
# Predicted class for 161.jpg : benign
# Class probability: 1.0
# Predicted class for 162.jpg : benign
# Class probability: 0.9999969
# Predicted class for 163.jpg : benign
# Class probability: 1.0
# Predicted class for 164.jpg : benign
# Class probability: 0.9999988
# Predicted class for 165.jpg : benign
# Class probability: 0.95495355
# Predicted class for 166.jpg : benign
# Class probability: 0.72199214
# Predicted class for 167.jpg : benign
# Class probability: 0.99641055
# Predicted class for 168.jpg : benign
# Class probability: 0.99999607
# Predicted class for 169.jpg : benign
# Class probability: 0.9999982
# Predicted class for 170.jpg : benign
# Class probability: 1.0
# Predicted class for 171.jpg : benign
# Class probability: 0.64001584
# Predicted class for 172.jpg : benign
# Class probability: 1.0
# Predicted class for 173.jpg : benign
# Class probability: 0.99929905
# Predicted class for 174.jpg : benign
# Class probability: 0.9999963
# Predicted class for 175.jpg : benign
# Class probability: 0.999759
# Predicted class for 176.jpg : benign
# Class probability: 0.99998176
# Predicted class for 177.jpg : benign
# Class probability: 0.99999225
# Predicted class for 178.jpg : benign
# Class probability: 0.99999976
# Predicted class for 179.jpg : malignant
# Class probability: 0.54797983
# Predicted class for 180.jpg : benign
# Class probability: 0.8630147
# Predicted class for 181.jpg : benign
# Class probability: 0.9999485
# Predicted class for 182.jpg : benign
# Class probability: 0.9993467
# Predicted class for 183.jpg : benign
# Class probability: 0.60673237
# Predicted class for 184.jpg : benign
# Class probability: 0.99999917
# Predicted class for 185.jpg : benign
# Class probability: 0.99999297
# Predicted class for 186.jpg : benign
# Class probability: 1.0
# Predicted class for 187.jpg : malignant
# Class probability: 0.9826329
# Predicted class for 188.jpg : benign
# Class probability: 1.0
# Predicted class for 189.jpg : benign
# Class probability: 0.9999987
# Predicted class for 190.jpg : benign
# Class probability: 0.9999778
# Predicted class for 191.jpg : benign
# Class probability: 0.9999831
# Predicted class for 192.jpg : benign
# Class probability: 0.6730909
# Predicted class for 193.jpg : malignant
# Class probability: 0.8729885
# Predicted class for 194.jpg : benign
# Class probability: 0.9999988
# Predicted class for 195.jpg : benign
# Class probability: 0.938363
# Predicted class for 196.jpg : benign
# Class probability: 1.0
# Predicted class for 197.jpg : benign
# Class probability: 0.99997866
# Predicted class for 198.jpg : benign
# Class probability: 0.99999845
# Predicted class for 199.jpg : benign
# Class probability: 0.9551692
# Predicted class for 200.jpg : benign
# Class probability: 0.9999994
# Predicted class for 201.jpg : benign
# Class probability: 0.99996805
# Predicted class for 202.jpg : benign
# Class probability: 0.99999964
# Predicted class for 203.jpg : benign
# Class probability: 0.9999988
# Predicted class for 204.jpg : malignant
# Class probability: 0.67911625
# Predicted class for 205.jpg : malignant
# Class probability: 0.9426545
# Predicted class for 206.jpg : benign
# Class probability: 0.98313695
# Predicted class for 207.jpg : benign
# Class probability: 0.9331081
# Predicted class for 208.jpg : benign
# Class probability: 0.9999999
# Predicted class for 209.jpg : malignant
# Class probability: 0.5836436
# Predicted class for 210.jpg : malignant
# Class probability: 0.61654127
# Predicted class for 211.jpg : benign
# Class probability: 0.9999994
# Predicted class for 212.jpg : benign
# Class probability: 0.99999905
# Predicted class for 213.jpg : benign
# Class probability: 0.73461664
# Predicted class for 214.jpg : benign
# Class probability: 0.99981534
# Predicted class for 215.jpg : benign
# Class probability: 0.999992
# Predicted class for 216.jpg : benign
# Class probability: 0.99119174
# Predicted class for 217.jpg : benign
# Class probability: 0.95850897
# Predicted class for 218.jpg : benign
# Class probability: 0.9648371
# Predicted class for 219.jpg : benign
# Class probability: 0.86247575
# Predicted class for 220.jpg : benign
# Class probability: 0.99582535
# Predicted class for 221.jpg : benign
# Class probability: 0.64815027
# Predicted class for 222.jpg : benign
# Class probability: 0.99999857
# Predicted class for 223.jpg : benign
# Class probability: 0.9999994
# Predicted class for 224.jpg : benign
# Class probability: 0.7478509
# Predicted class for 225.jpg : malignant
# Class probability: 0.74331653
# Predicted class for 226.jpg : benign
# Class probability: 0.98432434
# Predicted class for 227.jpg : benign
# Class probability: 0.9984238
# Predicted class for 228.jpg : benign
# Class probability: 0.57242143
# Predicted class for 229.jpg : benign
# Class probability: 0.99999964
# Predicted class for 230.jpg : benign
# Class probability: 0.99998856
# Predicted class for 231.jpg : benign
# Class probability: 0.9999999
# Predicted class for 232.jpg : benign
# Class probability: 0.999012
# Predicted class for 233.jpg : benign
# Class probability: 0.9999546
# Predicted class for 234.jpg : benign
# Class probability: 0.89766014
# Predicted class for 235.jpg : benign
# Class probability: 0.99999714
# Predicted class for 236.jpg : benign
# Class probability: 0.80628633
# Predicted class for 237.jpg : benign
# Class probability: 0.9598538
# Predicted class for 238.jpg : benign
# Class probability: 0.99204016
# Predicted class for 239.jpg : benign
# Class probability: 0.9772857
# Predicted class for 240.jpg : benign
# Class probability: 0.9999999
# Predicted class for 241.jpg : benign
# Class probability: 0.999985
# Predicted class for 242.jpg : benign
# Class probability: 0.9070298
# Predicted class for 243.jpg : benign
# Class probability: 0.9752939
# Predicted class for 244.jpg : malignant
# Class probability: 0.7122705
# Predicted class for 245.jpg : benign
# Class probability: 0.9999844
# Predicted class for 246.jpg : benign
# Class probability: 0.9999999
# Predicted class for 247.jpg : benign
# Class probability: 1.0
# Predicted class for 248.jpg : benign
# Class probability: 1.0
# Predicted class for 249.jpg : benign
# Class probability: 0.9999982
# Predicted class for 250.jpg : malignant
# Class probability: 0.5271911
# Predicted class for 251.jpg : benign
# Class probability: 0.64370847
# Predicted class for 252.jpg : benign
# Class probability: 1.0
# Predicted class for 253.jpg : benign
# Class probability: 0.95929074
# Predicted class for 254.jpg : benign
# Class probability: 0.9990208
# Predicted class for 255.jpg : benign
# Class probability: 0.62837756
# Predicted class for 256.jpg : benign
# Class probability: 0.9999826
# Predicted class for 257.jpg : benign
# Class probability: 0.9999994
# Predicted class for 258.jpg : benign
# Class probability: 0.76943785
# Predicted class for 259.jpg : benign
# Class probability: 0.99998975
# Predicted class for 260.jpg : benign
# Class probability: 0.9999999
# Predicted class for 261.jpg : benign
# Class probability: 1.0
# Predicted class for 262.jpg : benign
# Class probability: 1.0
# Predicted class for 263.jpg : benign
# Class probability: 1.0
# Predicted class for 264.jpg : benign
# Class probability: 0.92587143
# Predicted class for 265.jpg : benign
# Class probability: 0.6578854
# Predicted class for 266.jpg : benign
# Class probability: 0.9999995
# Predicted class for 267.jpg : benign
# Class probability: 0.99999976
# Predicted class for 268.jpg : benign
# Class probability: 0.8921588
# Predicted class for 269.jpg : benign
# Class probability: 0.99998665
# Predicted class for 270.jpg : benign
# Class probability: 0.99999976
# Predicted class for 271.jpg : benign
# Class probability: 1.0
# Predicted class for 272.jpg : benign
# Class probability: 0.8710951
# Predicted class for 273.jpg : benign
# Class probability: 0.8178479
# Predicted class for 274.jpg : benign
# Class probability: 1.0
# Predicted class for 275.jpg : benign
# Class probability: 0.99848783
# Predicted class for 276.jpg : malignant
# Class probability: 0.91222423
# Predicted class for 277.jpg : benign
# Class probability: 0.9794622
# Predicted class for 278.jpg : benign
# Class probability: 0.9999728
# Predicted class for 279.jpg : benign
# Class probability: 0.9990773
# Predicted class for 280.jpg : benign
# Class probability: 0.99999905
# Predicted class for 281.jpg : benign
# Class probability: 0.83299965
# Predicted class for 282.jpg : benign
# Class probability: 0.9999993
# Predicted class for 283.jpg : benign
# Class probability: 0.8812181
# Predicted class for 284.jpg : benign
# Class probability: 0.67697036
# Predicted class for 285.jpg : benign
# Class probability: 0.8265927
# Predicted class for 286.jpg : benign
# Class probability: 0.9987892
# Predicted class for 287.jpg : benign
# Class probability: 0.9999951
# Predicted class for 288.jpg : benign
# Class probability: 0.9992421
# Predicted class for 289.jpg : benign
# Class probability: 1.0
# Predicted class for 290.jpg : benign
# Class probability: 0.9999763
# Predicted class for 291.jpg : benign
# Class probability: 0.99999607
# Predicted class for 292.jpg : benign
# Class probability: 0.9999995
# Predicted class for 293.jpg : benign
# Class probability: 0.9999982
# Predicted class for 294.jpg : malignant
# Class probability: 0.9390112
# Predicted class for 295.jpg : benign
# Class probability: 0.99999607
# Predicted class for 296.jpg : benign
# Class probability: 1.0
# Predicted class for 297.jpg : benign
# Class probability: 0.99999917
# Predicted class for 298.jpg : benign
# Class probability: 0.9996845
# Predicted class for 299.jpg : benign
# Class probability: 1.0
# Predicted class for 300.jpg : benign
# Class probability: 0.99999833
# Predicted class for 301.jpg : benign
# Class probability: 0.8357613
# Predicted class for 302.jpg : malignant
# Class probability: 0.7465528
# Predicted class for 303.jpg : benign
# Class probability: 0.5325137
# Predicted class for 304.jpg : benign
# Class probability: 1.0
# Predicted class for 305.jpg : benign
# Class probability: 0.9632732
# Predicted class for 306.jpg : benign
# Class probability: 0.9528203
# Predicted class for 307.jpg : benign
# Class probability: 1.0
# Predicted class for 308.jpg : benign
# Class probability: 0.58669674
# Predicted class for 309.jpg : benign
# Class probability: 0.9997665
# Predicted class for 310.jpg : benign
# Class probability: 1.0
# Predicted class for 311.jpg : malignant
# Class probability: 0.72325057
# Predicted class for 312.jpg : benign
# Class probability: 0.99996674
# Predicted class for 313.jpg : malignant
# Class probability: 0.66000015
# Predicted class for 314.jpg : benign
# Class probability: 0.9998746
# Predicted class for 315.jpg : benign
# Class probability: 0.99999964
# Predicted class for 316.jpg : benign
# Class probability: 0.9843709
# Predicted class for 317.jpg : benign
# Class probability: 0.9999881
# Predicted class for 318.jpg : benign
# Class probability: 0.99996996
# Predicted class for 319.jpg : benign
# Class probability: 0.99999976
# Predicted class for 320.jpg : benign
# Class probability: 0.6884899
# Predicted class for 321.jpg : benign
# Class probability: 0.99999976
# Predicted class for 322.jpg : malignant
# Class probability: 0.8485019
# Predicted class for 323.jpg : malignant
# Class probability: 0.7590896
# Predicted class for 324.jpg : benign
# Class probability: 0.99999964
# Predicted class for 325.jpg : benign
# Class probability: 1.0
# Predicted class for 326.jpg : benign
# Class probability: 0.99128205
# Predicted class for 327.jpg : benign
# Class probability: 0.99991846
# Predicted class for 328.jpg : benign
# Class probability: 0.9739353
# Predicted class for 329.jpg : benign
# Class probability: 0.9998746
# Predicted class for 330.jpg : malignant
# Class probability: 0.5915206
# Predicted class for 331.jpg : benign
# Class probability: 0.99999833
# Predicted class for 332.jpg : benign
# Class probability: 1.0
# Predicted class for 333.jpg : benign
# Class probability: 0.99999976
# Predicted class for 334.jpg : benign
# Class probability: 0.9999968
# Predicted class for 335.jpg : benign
# Class probability: 0.9999993
# Predicted class for 336.jpg : benign
# Class probability: 1.0
# Predicted class for 337.jpg : benign
# Class probability: 0.95782954
# Predicted class for 338.jpg : malignant
# Class probability: 0.9418299
# Predicted class for 339.jpg : benign
# Class probability: 0.72436595
# Predicted class for 340.jpg : benign
# Class probability: 0.87771934
# Predicted class for 341.jpg : benign
# Class probability: 0.99999917
# Predicted class for 342.jpg : malignant
# Class probability: 0.540663
# Predicted class for 343.jpg : benign
# Class probability: 0.99999785
# Predicted class for 344.jpg : benign
# Class probability: 0.99999833
# Predicted class for 345.jpg : benign
# Class probability: 0.776218
# Predicted class for 346.jpg : benign
# Class probability: 0.8464842
# Predicted class for 347.jpg : benign
# Class probability: 0.99997616
# Predicted class for 348.jpg : benign
# Class probability: 0.99955755
# Predicted class for 349.jpg : benign
# Class probability: 0.9274816
# Predicted class for 350.jpg : benign
# Class probability: 1.0
# Predicted class for 351.jpg : benign
# Class probability: 0.9999988
# Predicted class for 352.jpg : benign
# Class probability: 0.99999475
# Predicted class for 353.jpg : benign
# Class probability: 0.9986952
# Predicted class for 354.jpg : benign
# Class probability: 0.99999976
# Predicted class for 355.jpg : benign
# Class probability: 0.99516535
# Predicted class for 356.jpg : benign
# Class probability: 0.9999616
# Predicted class for 357.jpg : benign
# Class probability: 0.9999515
# Predicted class for 358.jpg : benign
# Class probability: 0.9999963
# Predicted class for 359.jpg : benign
# Class probability: 0.5636471
# Predicted class for 360.jpg : benign
# Class probability: 1.0
